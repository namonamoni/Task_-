# %%
#https://codechacha.com/ko/python-read-write-json-file/
#JSON 파일을 읽어서 dict 객체로 만들 수 있습니다.
#다음은 AnswerMe1997.json 파일을 읽어서 dict로 가져오는 예제입니다.

# %%
import json
file_path = "AnswerMe_1994.json"

# %%
with open(file_path, "r", encoding='UTF-8-sig') as json_file:
    json_data = json.load(json_file)

# %%
json_data
# Out:
# {'AnswerMe_1994': [{'actor': '성나정',
#    'age': '19',
#    'sex': '여',
#    'birthplace': '경남 마산',
#    "in_one's": '10대',
#    'play': '대학생',
#    'Ksubtitles': '아..진짜 어디갔지..',
#    'Taggingcorpus': '아__02/IC+./SF+./SF+진짜/NNG 어디/NP+가/VV+았/EP+지/EF+./SF+./SF'},
#   {'actor': '조윤진',
#    'age': '19',
#    'sex': '여',
#    'birthplace': '전남 여수',
#    "in_one's": '10대',
#    'play': '대학생',
#    'Ksubtitles': '아니, 오늘이사한집 맞냐? 먼지하나없네 먼지하나없어..',
#    'Taggingcorpus': '/SS+아니__02/IC+,/SP 오늘/NNG+이사__14/NNG+한집__01/NNG 맞__01/VV+냐/EF+?/SF 먼지__01/NNG+하나/NR+없__01/VA+네/EC 먼지__01/NNG+하나/NR+없__01/VA+어/EF+./SF+./SF+/SS'},
#   {'actor': '조윤진',
#    'age': '19',
#    'sex': '여',
#    'birthplace': '전남 여수',
#    "in_one's": '10대',
#    'play': '대학생',
#    'Ksubtitles': '후',
#    'Taggingcorpus': '후__08/NNG'},
#   {'actor': '조윤진',
#    'age': '19',
#    'sex': '여',
#    'birthplace': '전남 여수',
#    "in_one's": '10대',
#    'play': '대학생',
#    'Ksubtitles': '근데 닌 뭐찾냐',
# ...

# %%
len(json_data)
# Out:
# 1

# %%
len(json_data['AnswerMe_1994'])#우와 23980개의 대사가 있구나!
# Out:
# 23980

# %%
json_data['return_object'].keys() #result의 내부에 retutn_object내에 있는 키들을 보여주기 위함임 문장에 집중
